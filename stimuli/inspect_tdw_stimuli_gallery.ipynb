# %% [markdown]
# # Inspect TDW stimuli
#
# This notebook allows us to inspect images from the features of variation that we identified in our TDW pre-regristration:
# - varyHorizontal (can be "stable" or "unstable" --tbd on precarity)
# - varyScale (can be "stable" or "unstable")
# - varyNumber (only stable)

# %%
#!pip install h5py
import warnings
import os
import h5py
import numpy as np
from PIL import Image 
import io
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Function to load png files as a gallery for viewing

# %%
from IPython.display import HTML, Image

def _src_from_data(data):
    """Base64 encodes image bytes for inclusion in an HTML img element"""
    img_obj = Image(data=data)
    for bundle in img_obj._repr_mimebundle_():
        for mimetype, b64value in bundle.items():
            if mimetype.startswith('image/'):
                return f'data:{mimetype};base64,{b64value}'

def gallery(images, row_height='auto'):
    """Shows a set of images in a gallery that flexes with the width of the notebook.
    
    Parameters
    ----------
    images: list of str or bytes
        URLs or bytes of images to display

    row_height: str
        CSS height value to assign to all images. Set to 'auto' by default to show images
        with their native dimensions. Set to a value like '250px' to make all rows
        in the gallery equal height.
    """
    figures = []
    for image in images:
        if isinstance(image, bytes):
            src = _src_from_data(image)
            caption = ''
        else:
            src = image
            caption = f'<figcaption style="font-size: 0.4em">{image}</figcaption>'
        figures.append(f'''
            <figure style="margin: 5px !important;">
              <img src="{src}" style="height: {row_height}">
              {caption}
            </figure>
        ''')
    return HTML(data=f'''
        <div style="display: flex; flex-flow: row wrap; text-align: center;">
        {''.join(figures)}
        </div>
    ''')

# %% [markdown]
# #### Please specify a condition below to generate the gallery

# %%
#condition = 'varyScale' 
#condition = 'varyHorizontal'
#condition = 'varyNumber'

# %% [markdown]
# ## Load .png stims from s3 and render in gallery

# %%
## helper to build image urls
def build_s3_url(path, bucket_name = 'curiotower-tdw'):    
    return 'https://{}.s3.amazonaws.com/{}'.format(bucket_name, path.split('/')[-1])

# %%
## where are your stimulus images stored?
data_dir = 'tdw_png'
bucket_name = 'curiotower'
stim_version = 'tdw'
dataset_name = '{}-{}'.format(bucket_name, stim_version)

## get a list of paths to each one
full_stim_paths = [os.path.abspath(os.path.join(data_dir,i)) for i in os.listdir(data_dir)]
full_stim_paths = [i for i in full_stim_paths if i.split('/')[-1] != '.DS_Store'] ## bleh
print('We have {} images to evaluate.'.format(len(full_stim_paths)))



image_urls = [build_s3_url(p) for p in full_stim_paths]

#image_urls = [x for x in image_urls if condition in x]
print(len(image_urls))
# Out:
# We have 146 images to evaluate.
# 146

# %%
#full_stim_paths = [i for i in full_stim_paths if i.split('/')[-1] != '.DS_Store']
#print(full_stim_paths)

# %% [markdown]
# ### Visualize the png files in a gallery view

# %%
print('SHOWING TOWERS FOR THE {} DIR'.format(dataset_name))
gallery(image_urls, row_height='150px')
# Out:
# SHOWING TOWERS FOR THE curiotower-tdw DIR
#         <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0002_1.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0002_1.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0003_0.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0003_0.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0003_1.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0003_1.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0002_0.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0002_0.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0001_1.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0001_1.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0000_0.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0000_0.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0000_1.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0000_1.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0001_0.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0001_0.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0005_0.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0005_0.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0004_1.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0004_1.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0004_0.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0004_0.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0005_1.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0005_1.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0006_0.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0006_0.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0007_1.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0007_1.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0007_0.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0007_0.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0006_1.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0006_1.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0001_0.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0001_0.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0000_1.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0000_1.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0000_0.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0000_0.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0001_1.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0001_1.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0002_0.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0002_0.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0003_1.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0003_1.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0003_0.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_2_high_0003_0.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_4_high_0002_1.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://c
