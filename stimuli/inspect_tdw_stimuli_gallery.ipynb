# %% [markdown]
# # Inspect TDW stimuli
#
# This notebook allows us to inspect images from the features of variation that we identified in our TDW pre-regristration:
# - varyHorizontal (can be "stable" or "unstable" --tbd on precarity)
# - varyScale (can be "stable" or "unstable")
# - varyNumber (only stable)

# %%
#!pip install h5py
import warnings
import os
import h5py
import numpy as np
from PIL import Image 
import io
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Function to load png files as a gallery for viewing

# %%
from IPython.display import HTML, Image

def _src_from_data(data):
    """Base64 encodes image bytes for inclusion in an HTML img element"""
    img_obj = Image(data=data)
    for bundle in img_obj._repr_mimebundle_():
        for mimetype, b64value in bundle.items():
            if mimetype.startswith('image/'):
                return f'data:{mimetype};base64,{b64value}'

def gallery(images, row_height='auto'):
    """Shows a set of images in a gallery that flexes with the width of the notebook.
    
    Parameters
    ----------
    images: list of str or bytes
        URLs or bytes of images to display

    row_height: str
        CSS height value to assign to all images. Set to 'auto' by default to show images
        with their native dimensions. Set to a value like '250px' to make all rows
        in the gallery equal height.
    """
    figures = []
    for image in images:
        if isinstance(image, bytes):
            src = _src_from_data(image)
            caption = ''
        else:
            src = image
            caption = f'<figcaption style="font-size: 0.4em">{image}</figcaption>'
        figures.append(f'''
            <figure style="margin: 5px !important;">
              <img src="{src}" style="height: {row_height}">
              {caption}
            </figure>
        ''')
    return HTML(data=f'''
        <div style="display: flex; flex-flow: row wrap; text-align: center;">
        {''.join(figures)}
        </div>
    ''')

# %% [markdown]
# #### Please specify a condition below to generate the gallery

# %%
condition = 'varyScale' 
#condition = 'varyHorizontal'
#condition = 'varyNumber'

# %% [markdown]
# ## Load .png stims from s3 and render in gallery

# %%
## helper to build image urls
def build_s3_url(path, bucket_name = 'curiotower-tdw'):    
    return 'https://{}.s3.amazonaws.com/{}'.format(bucket_name, path.split('/')[-1])

# %%
## where are your stimulus images stored?
data_dir = 'tdw_png'
bucket_name = 'curiotower'
stim_version = 'curiodrop'
dataset_name = '{}_{}'.format(bucket_name, stim_version)

## get a list of paths to each one
full_stim_paths = [os.path.abspath(os.path.join(data_dir,i)) for i in os.listdir(data_dir)]
full_stim_paths = [i for i in full_stim_paths if i.split('/')[-1] != '.DS_Store'] ## bleh
print('We have {} images to evaluate.'.format(len(full_stim_paths)))



image_urls = [build_s3_url(p) for p in full_stim_paths]

image_urls = [x for x in image_urls if condition in x]
print(len(image_urls))
# Out:
# We have 247 images to evaluate.
# 100

# %% [markdown]
# ### Visualize the png files in a gallery view

# %%
print('SHOWING TOWERS FOR THE {} CONDITION'.format(condition))
gallery(image_urls, row_height='150px')
# Out:
# SHOwING TOWERS FOR THE varyScale CONDITION
#         <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0039.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0039.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0005.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0005.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0011.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0011.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0010.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0010.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0004.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0004.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0038.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0038.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0012.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0012.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0006.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0006.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0007.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0007.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0013.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0013.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0017.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0017.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0003.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0003.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0002.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0002.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0016.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0016.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0000.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0000.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0014.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0014.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0028.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0028.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0029.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0029.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0015.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0015.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0001.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0001.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0099.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0099.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0066.png" style="height: 150px">
#               <figcaption style="font-size: 0.4em">https://curiotower-tdw.s3.amazonaws.com/curiotower_varyScale_stable_8_0066.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="https://curiotower-tdw.s3.amazonaws.com/curioto
